# %% [markdown]
# <a href="https://colab.research.google.com/github/anajuliafrancoo/Aulas-PCM/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
arquivo = files.upload()
img_name = next(iter(arquivo))

image = cv2.imread(img_name)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
dist = np.zeros(256, dtype=int)

for i in range(image.shape[0]):
  for j in range(image.shape[1]):
    value = image[i,j]
    dist[value] += 1

indexes = list(range(len(dist)))
plt.figure(figsize=(6,4))
plt.bar(indexes, dist, color='blue')
plt.xlabel("Niveis")
plt.ylabel("Pixels")
plt.show()
